# %% [markdown]
# <a href="https://colab.research.google.com/github/ouharu/datasets/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_openml

# %%
import scipy.io as sio
import numpy as np

#load
data = sio.loadmat('data.mat')

# %%
y.shape
# Out:
# (70000,)

# %%
! git clone git@github.com:ouharu/datasets.git
# Out:
# Cloning into 'datasets'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
